# %% [markdown]
# Step-1 importing libraries

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ShashikumarAmgoth(Mu\AppData\Roaming\nltk_dat
# [nltk_data]     a...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\ShashikumarAmgoth(Mu\AppData\Roaming\nltk_dat
# [nltk_data]     a...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
# Sample text
text = "NLT is a powerful library for natural language processing"

# tokenize the words
tokenized_words=word_tokenize(text)

# performing POS tagging 
pos_tags=pos_tag(tokenized_words)

print("Original Text:")
print(text)

print("\nPoS Tagging Result:")
for word, pos_tag in pos_tags:
    print(f"{word}: {pos_tag}")
# Out:
# Original Text:
# NLT is a powerful library for natural language processing
#
# PoS Tagging Result:
# NLT: NNP
# is: VBZ
# a: DT
# powerful: JJ
# library: NN
# for: IN
# natural: JJ
# language: NN
# processing: NN

# %% [markdown]
# Using Spacy library

# %%
import spacy
# Load the English language model
nlp = spacy.load("en_core_web_sm")

# Sample text
text = "NLT is a powerful library for natural language processing"

# Process the text with SpaCy
doc = nlp(text)

print("Original Text: ", text)
print("PoS Tagging Result:")
for token in doc:
    print(f"{token.text}: {token.pos_}")
# Out:
# Original Text:  NLT is a powerful library for natural language processing
# PoS Tagging Result:
# NLT: PROPN
# is: AUX
# a: DET
# powerful: ADJ
# library: NOUN
# for: ADP
# natural: ADJ
# language: NOUN
# processing: NOUN
